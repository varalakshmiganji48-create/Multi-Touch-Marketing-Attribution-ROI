# %% [markdown]
# # Day 2 - Data Understanding and Exploration
#
# ## Objective:
# Understand the structure of the marketing dataset,
# analyze customer and campaign features,
# and identify important patterns for marketing attribution analysis.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/digital_marketing_campaign_dataset.csv")

# %%
df.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'Income', 'CampaignChannel',
#        'CampaignType', 'AdSpend', 'ClickThroughRate', 'ConversionRate',
#        'WebsiteVisits', 'PagesPerVisit', 'TimeOnSite', 'SocialShares',
#        'EmailOpens', 'EmailClicks', 'PreviousPurchases', 'LoyaltyPoints',
#        'AdvertisingPlatform', 'AdvertisingTool', 'Conversion'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CustomerID           8000 non-null   int64
#  1   Age                  8000 non-null   int64
#  2   Gender               8000 non-null   object
#  3   Income               8000 non-null   int64
#  4   CampaignChannel      8000 non-null   object
#  5   CampaignType         8000 non-null   object
#  6   AdSpend              8000 non-null   float64
#  7   ClickThroughRate     8000 non-null   float64
#  8   ConversionRate       8000 non-null   float64
#  9   WebsiteVisits        8000 non-null   int64
#  10  PagesPerVisit        8000 non-null   float64
#  11  TimeOnSite           8000 non-null   float64
#  12  SocialShares         8000 non-null   int64
#  13  EmailOpens           8000 non-null   int64
#  14  EmailClicks          8000 non-null   int64
# ...

# %%
df.describe()
# Out:
#         CustomerID          Age         Income      AdSpend  ClickThroughRate  \
# count   8000.00000  8000.000000    8000.000000  8000.000000       8000.000000
# mean   11999.50000    43.625500   84664.196750  5000.944830          0.154829
# std     2309.54541    14.902785   37580.387945  2838.038153          0.084007
# min     8000.00000    18.000000   20014.000000   100.054813          0.010005
# 25%     9999.75000    31.000000   51744.500000  2523.221165          0.082635
# 50%    11999.50000    43.000000   84926.500000  5013.440044          0.154505
# 75%    13999.25000    56.000000  116815.750000  7407.989369          0.228207
# max    15999.00000    69.000000  149986.000000  9997.914781          0.299968
#
#        ConversionRate  WebsiteVisits  PagesPerVisit   TimeOnSite  \
# count     8000.000000    8000.000000    8000.000000  8000.000000
# mean         0.104389      24.751625       5.549299     7.727718
# std          0.054878      14.312269       2.607358     4.228218
# ...

# %%
df.nunique()
# Out:
# CustomerID             8000
# Age                      52
# Gender                    2
# Income                 7789
# CampaignChannel           5
# CampaignType              4
# AdSpend                8000
# ClickThroughRate       8000
# ConversionRate         8000
# WebsiteVisits            50
# PagesPerVisit          8000
# TimeOnSite             8000
# SocialShares            100
# EmailOpens               20
# EmailClicks              10
# PreviousPurchases        10
# LoyaltyPoints          3983
# AdvertisingPlatform       1
# AdvertisingTool           1
# Conversion                2
# dtype: int64

# %%
df['CampaignChannel'].value_counts()
# Out:
# CampaignChannel
# Referral        1719
# PPC             1655
# Email           1557
# SEO             1550
# Social Media    1519
# Name: count, dtype: int64

# %%
df['CampaignType'].value_counts()
# Out:
# CampaignType
# Conversion       2077
# Awareness        1988
# Consideration    1988
# Retention        1947
# Name: count, dtype: int64

# %%
df['Conversion'].value_counts()
# Out:
# Conversion
# 1    7012
# 0     988
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))

df['CampaignChannel'].value_counts().plot(kind='bar')

plt.title("Campaign Channel Distribution")
plt.xlabel("Campaign Channel")
plt.ylabel("Number of Customers")

plt.xticks(rotation=45)

plt.show()

# %%
plt.figure(figsize=(6,4))

df['Conversion'].value_counts().plot(kind='bar')

plt.title("Conversion Distribution")
plt.xlabel("Conversion Status")
plt.ylabel("Count")

plt.show()

# %%
df['Conversion'].mean()*100
# Out:
# np.float64(87.64999999999999)

# %% [markdown]
# # Day 2 Summary
#
# ## Data Understanding & Exploration
#
# ### Key Findings:
# - Dataset contains 8000 customer marketing records with 20 features.
# - Data includes customer demographics, campaign details, advertising metrics, and conversion outcomes.
# - No missing values and duplicate records were found.
#
# ### Marketing Insights:
# - Referral is the most used campaign channel with 1719 records.
# - PPC is the second highest channel with 1655 records.
# - Conversion campaigns are the most common campaign type.
# - The dataset contains 7012 converted and 988 non-converted customers.
#
# ### Observation:
# - The conversion rate is significantly high, indicating the dataset may be simulated or pre-filtered.
